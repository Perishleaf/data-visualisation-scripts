# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import math 

import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
# %%time
# Import xlsx file and store each sheet in to a df list
xl_file = pd.ExcelFile('./AU_cases.xlsx',)

dfs = {sheet_name: xl_file.parse(sheet_name) 
          for sheet_name in xl_file.sheet_names}

# Data from each sheet can be accessed via key
keyList = list(dfs.keys())
# Out:
# CPU times: user 177 ms, sys: 10.4 ms, total: 187 ms
# Wall time: 194 ms

# %%
dfs[keyList[0]]
# Out:
#     Case Number Country-wide Case Number State-wide Confirmed Date       City  \
# 0                          1                    1st     2020-01-25  Melbourne
# 1                          2                    1st     2020-01-25     Sydney
# 2                          3                    2nd     2020-01-25     Sydney
# 3                          4                    3rd     2020-01-25     Sydney
# 4                          5                    4th     2020-01-27     Sydney
# ..                       ...                    ...            ...        ...
# 87                        88                   13th     2020-03-09  Melbourne
# 88                        89                   14th     2020-03-09  Melbourne
# 89                        90                   15th     2020-03-09  Melbourne
# 90                        91                    5th     2020-03-09      Perth
# 91                        92                    6th     2020-03-09      Perth
#
#    State                       Origin Date entering AU/NZ  Gender  Age  \
# 0    VIC                          NaN                 NaT    Male  50s
# 1    NSW                          NaN          2020-01-16    Male  30s
# 2    NSW                          NaN                 NaT    Male  40s
# 3    NSW                          NaN                 NaT    Male  50s
# 4    NSW                          NaN          2020-01-24  Female  20s
# ..   ...                          ...                 ...     ...  ...
# 87   VIC                          NaN                 NaT    Male  50s
# 88   VIC                          NaN          2020-03-06  Female  20s
# 89   VIC                          NaN          2020-03-06  Female  50s
# 90    WA  human-to-human transmission                 NaT  Female  60s
# 91    WA  human-to-human transmission                 NaT    Male  40s
#
#          Recovered Date                                              Notes  \
# 0                   NaN  A Chinese national visiting Melbourne from Wuh...
# 1   2020-01-30 00:00:00                          Flew from Shenzhen, China
# 2   2020-01-30 00:00:00                             Flew from Wuhan, China
# 3   2020-02-27 00:00:00                             Flew from Wuhan, China
# 4   2020-02-10 00:00:00  The woman (UNSW student) flew into Sydney Airp...
# ..                  ...                                                ...
# 87                  NaN  A male who was on the same flight from the USA...
# 88                  NaN  A female returned from Colorado in the USA on ...
# 89                  NaN    A female returned from Tehran on flight MH0149.
# 90                  NaN  A woman is believed to have contracted the vir...
# 91                  NaN  The latest patient is the son of a woman who r...
#
#                                        News Reference
# 0   https://www.theage.com.au/national/victoria/co...
# 1   https://www.hawkesburygazette.com.au/story/660...
# 2   https://www.hawkesburygazette.com.au/story/660...
# 3                                                 NaN
# 4   https://7news.com.au/news/health/coronavirus-i...
# ..                                                ...
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90  https://www.abc.net.au/news/2020-03-09/fifth-c...
# 91  https://7news.com.au/lifestyle/health-wellbein...
#
# [92 rows x 12 columns]
